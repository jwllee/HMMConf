# %%
from scipy import stats
import pandas as pd
import numpy as np
import os, sys
import matplotlib.pyplot as plt
import seaborn as sns

# %%
RESULT_DIR = '../../results/real-life/'
RESULT_FP = os.path.join(RESULT_DIR, 'road-traffic.csv')

# %%
result_df = pd.read_csv(RESULT_FP)
result_df.sort_values('caseid', inplace=True)

# %%
result_df.head()
# Out:
#    caseid  case_length                    activity  final_conformance  \
# 0    A100            1                 Create Fine           1.000000
# 1    A100            2                   Send Fine           1.000000
# 2    A100            3    Insert Fine Notification           0.892776
# 3    A100            4  Send for Credit Collection           0.559274
# 4  A10000            1                 Create Fine           1.000000
#
#    avg_final_conformance  sum_mode_distance  mode_completeness  \
# 0               1.000000                0.0                1.0
# 1               1.000000                0.0                1.0
# 2               0.964259                0.0                1.0
# 3               0.863012                0.0                1.0
# 4               1.000000                0.0                1.0
#
#    sum_exp_distance  exp_completeness  sequence_likelihood
# 0      0.000000e+00          1.000000             0.999860
# ...

# %%
result_df.describe()
# Out:
#          case_length  final_conformance  avg_final_conformance  \
# count  305496.000000      305496.000000          305496.000000
# mean        2.442277           0.884403               0.962892
# std         1.126451           0.167654               0.052189
# min         1.000000           0.000000               0.416667
# 25%         1.000000           0.892776               0.964259
# 50%         2.000000           1.000000               1.000000
# 75%         3.000000           1.000000               1.000000
# max         8.000000           1.000000               1.000000
#
#        sum_mode_distance  mode_completeness  sum_exp_distance  \
# count      305496.000000      305496.000000      3.054960e+05
# mean            0.000749           0.999872      1.448253e-02
# std             0.027230           0.004688      3.276110e-02
# min             0.000000           0.800000      0.000000e+00
# 25%             0.000000           1.000000      0.000000e+00
# ...

# %%
result_df.describe()
# Out:
#          case_length  final_conformance  avg_final_conformance  \
# count  305496.000000      305496.000000          305496.000000
# mean        2.442277           0.884403               0.962892
# std         1.126451           0.167654               0.052189
# min         1.000000           0.000000               0.416667
# 25%         1.000000           0.892776               0.964259
# 50%         2.000000           1.000000               1.000000
# 75%         3.000000           1.000000               1.000000
# max         8.000000           1.000000               1.000000
#
#        sum_mode_distance  mode_completeness  sum_exp_distance  \
# count      305496.000000      305496.000000      3.054960e+05
# mean            0.000749           0.999872      1.448253e-02
# std             0.027230           0.004688      3.276110e-02
# min             0.000000           0.800000      0.000000e+00
# 25%             0.000000           1.000000      0.000000e+00
# ...

# %%
result_df.caseid.unique().shape
# Out:
# (80016,)

# %%
result_df.shape[0]
# Out:
# 305496
